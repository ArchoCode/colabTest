# %%
# !git clone https://github.com/samitha9125/SinhalaTextClassification.git
# Out:
# Cloning into 'SinhalaTextClassification'...
# remote: Enumerating objects: 46, done.
# remote: Total 46 (delta 0), reused 0 (delta 0), pack-reused 46
# Unpacking objects: 100% (46/46), done.

# %%
# %cd SinhalaTextClassification/
# Out:
# /content/SinhalaTextClassification

# %%
# %cd Code/
# Out:
# /content/SinhalaTextClassification/Code

# %%
# !python Code.py
# Out:
# 2021-01-03 15:46:08.313920: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Loading model. Please wait ...
# 2021-01-03 15:46:09.895809: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-01-03 15:46:09.897037: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-01-03 15:46:09.935411: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-01-03 15:46:09.935980: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# ...
